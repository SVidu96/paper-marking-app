# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# Download NLTK resources 
nltk.download('punkt')

# Load the CSV file into a DataFrame
df = pd.read_csv('D:/Projects/Online paper marking system/New folder (3)/ML model/output.csv')

# Convert the columns to strings 
df['responses__'] = df['responses__'].astype(str)
df['patterns__001'] = df['patterns__001'].astype(str)
df['patterns__002'] = df['patterns__002'].astype(str)
df['patterns__003'] = df['patterns__003'].astype(str)

# Tokenize text for each column
df['tokens_responses'] = df['responses__'].apply(word_tokenize)
df['tokens_patterns_001'] = df['patterns__001'].apply(word_tokenize)
df['tokens_patterns_002'] = df['patterns__002'].apply(word_tokenize)
df['tokens_patterns_003'] = df['patterns__003'].apply(word_tokenize)

# Define the target variables (responses to each question)
y_responses = df['responses__']
y_001 = df['patterns__001']
y_002 = df['patterns__002']
y_003 = df['patterns__003']

# Define the input features (TF-IDF vectors) for each question
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform text data for each pattern
X_responses = tfidf_vectorizer.fit_transform(df['responses__'])
X_patterns_001 = tfidf_vectorizer.transform(df['patterns__001'])
X_patterns_002 = tfidf_vectorizer.transform(df['patterns__002'])
X_patterns_003 = tfidf_vectorizer.transform(df['patterns__003'])

# Split the data into training and testing sets for each question
X_train_responses, X_test_responses, y_train_responses, y_test_responses = train_test_split(X_responses, y_responses, test_size=0.2, random_state=42)
X_train_001, X_test_001, y_train_001, y_test_001 = train_test_split(X_patterns_001, y_001, test_size=0.2, random_state=42)
X_train_002, X_test_002, y_train_002, y_test_002 = train_test_split(X_patterns_002, y_002, test_size=0.2, random_state=42)
X_train_003, X_test_003, y_train_003, y_test_003 = train_test_split(X_patterns_003, y_003, test_size=0.2, random_state=42)

# Initialize classifiers for each question
rf_model_001 = RandomForestClassifier(n_estimators=100, random_state=42)
svm_model_002 = SVC(kernel='linear', C=1)
gb_model_003 = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=42)

# Train the models for each question
rf_model_001.fit(X_train_responses, y_train_001)
svm_model_002.fit(X_train_001, y_train_002)
gb_model_003.fit(X_train_002, y_train_003)

# Evaluate the models on the test set for each question
y_pred_001 = rf_model_001.predict(X_test_responses)
y_pred_002 = svm_model_002.predict(X_test_001)
y_pred_003 = gb_model_003.predict(X_test_002)

# Print classification reports for each question
print("Classification Report for patterns__001:")
print(classification_report(y_test_001, y_pred_001))

print("Classification Report for patterns__002:")
print(classification_report(y_test_002, y_pred_002))

print("Classification Report for patterns__003:")
print(classification_report(y_test_003, y_pred_003))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Supun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Classification Report for patterns__001:
#                                                                               precision    recall  f1-score   support
#
#                                               Define an expert system in AI?       0.00      0.00      0.00       1.0
#                                                       Describe decision tree       0.00      0.00      0.00       1.0
#                          Explain program documentation. Why is it important?       0.00      0.00      0.00       0.0
#                                          What Are recurrent neural networks?       0.00      0.00      0.00       1.0
#                                                What are Arbitration Schemes?       0.00      0.00      0.00       1.0
#                                              What are Asynchronous Counters?       0.00      0.00      0.00       1.0
#                                                         What are Bus Cycles?       0.00      0.00      0.00       0.0
#                            What are Common Pitfalls in computer performance?       0.00      0.00      0.00       1.0
#                                                           What are Decoders?       0.00      0.00      0.00       0.0
#                                                     What are Demultiplexers?       0.00      0.00      0.00       0.0
#                                                             What are Deques?       0.00      0.00      0.00       1.0
#                                              What are Distributed Databases?       0.00      0.00      0.00       1.0
#                                                           What are Encoders?       0.00      0.00      0.00       0.0
#                                            What are Evolutionary Strategies?       0.00      0.00      0.00       1.0
#                          What are Generalization Bounds in machine learning?       0.00      0.00      0.00       1.0
#                                                 What are Genetic Algorithms?       0.00      0.00      0.00       0.0
#                                                            What are Kernels?       0.00      0.00      0.00       0.0
#                                          What are Memory Addressing Schemes?       0.00      0.00      0.00       0.0
#                                       What are Multiple Issue Architectures?       0.00      0.00      0.00       0.0
#                                                       What are Multiplexers?       0.00      0.00      0.00       1.0
#                                                      What are Pin Functions?       0.00      0.00      0.00       1.0
#                                                          What are Processes?       0.00      0.00      0.00       1.0
#                                              What are Scheduling Algorithms?       0.00      0.00      0.00       1.0
#                                            What are Software Process Models?       0.00      0.00      0.00       0.0
#                                               What are Synchronous Counters?       0.00      0.00      0.00       0.0
#                                               What are asymptotic notations?       0.00      0.00      0.00       0.0
#                         What are logical connectives in propositional logic?       0.00      0.00      0.00       0.0
#                                                    What are neural networks?       0.00      0.00      0.00       0.0
#                                What are time-space trade offs in algorithms?       0.00      0.00      0.00       0.0
#                                  What is BCNF? How it is different from 3NF?       0.00      0.00      0.00       1.0
#                                                 What is Basic I/O Interface?       0.00      0.00      0.00       0.0
#                                                         What is CAP Theorem?       0.00      0.00      0.00       1.0
#                                          What is Computational Intelligence?       0.00      0.00      0.00       1.0
#                                                    What is Data Warehousing?       0.00      0.00      0.00       0.0
#                                                     What is Disk Scheduling?       0.00      0.00      0.00       0.0
#                                                   What is First-Order Logic?       0.00      0.00      0.00       1.0
#                                           What is Internal Bus Architecture?       0.00      0.00      0.00       0.0
#                                                          What is JavaScript?       0.00      0.00      0.00       1.0
#                                                  What is Memory Interfacing?       0.00      0.00      0.00       0.0
#                                                   What is Memory Management?       0.00      0.00      0.00       1.0
#                     What is Planning and Scheduling in software development?       0.00      0.00      0.00       1.0
#                                                     What is Polish Notation?       0.00      0.00      0.00       1.0
#                                      What is Programmable Logic Array (PLA)?       0.00      0.00      0.00       0.0
#                                                               What is React?       0.00      0.00      0.00       0.0
#                                    What is Requirements Engineering Process?       0.00      0.00      0.00       1.0
#                             What is Risk Management in software development?       0.00      0.00      0.00       0.0
#                                          What is a Clock Generation Circuit?       0.00      0.00      0.00       1.0
#                                        What is a degree of relation in DBMS?       0.00      0.00      0.00       1.0
#                                                       What is a syntax error       0.00      0.00      0.00       0.0
#                                                              What is an API?       0.00      0.00      0.00       1.0
#                                                            What is big data?       0.00      0.00      0.00       0.0
#                                                          What is blockchain?       0.00      0.00      0.00       0.0
#                                                        What is data science?       0.00      0.00      0.00       1.0
#                                            What is dimensionality reduction?       0.00      0.00      0.00       1.0
#                               What is event logging in software development?       0.00      0.00      0.00       1.0
#                       What is existential quantification in predicate logic?       0.00      0.00      0.00       1.0
#                                                          What is networking?       0.00      0.00      0.00       1.0
#                                                         What is programming?       0.00      0.00      0.00       1.0
#                                                 What is propositional logic?       0.00      0.00      0.00       0.0
#                                                           What is recursion?       0.00      0.00      0.00       1.0
#                    What is the Theory of Generalization in machine learning?       0.00      0.00      0.00       0.0
#     What is the difference between Training and Testing in machine learning?       0.00      0.00      0.00       1.0
# What is the difference between supervised and unsupervised machine learning?       0.00      0.00      0.00       0.0
#                         What is universal quantification in predicate logic?       0.00      0.00      0.00       0.0
#                                                What is virtual reality (VR)?       0.00      0.00      0.00       1.0
#                                                     What is virtual reality?       0.00      0.00      0.00       0.0
#
#                                                                     accuracy                           0.00      35.0
#                                                                    macro avg       0.00      0.00      0.00      35.0
#                                                                 weighted avg       0.00      0.00      0.00      35.0
#
# Classification Report for patterns__002:
#                                                                    precision    recall  f1-score   support
#
#                                                                 0       0.17      1.00      0.29         6
#                  Explain Arbitration Schemes in computer systems.       0.00      0.00      0.00         1
#               Explain Asynchronous Counters in computer hardware.       0.00      0.00      0.00         1
#                     Explain CAP Theorem in distributed databases.       0.00      0.00      0.00         1
#                                 Explain Clock Generation Circuit.       0.00      0.00      0.00         1
#                      Explain Common Pitfalls in computer systems.       0.00      0.00      0.00         1
#                               Explain Computational Intelligence.       0.00      0.00      0.00         1
#                           Explain Deques in computer programming.       0.00      0.00      0.00         1
#                                    Explain Distributed Databases.       0.00      0.00      0.00         1
#                                  Explain Evolutionary Strategies.       0.00      0.00      0.00         1
#                                        Explain First-Order Logic.       0.00      0.00      0.00         1
#                                    Explain Generalization Bounds.       0.00      0.00      0.00         1
#                                    Explain JavaScript data types.       0.00      0.00      0.00         1
#                                        Explain Memory Management.       0.00      0.00      0.00         1
#                        Explain Multiplexers in computer hardware.       0.00      0.00      0.00         1
#                                            Explain Pin Functions.       0.00      0.00      0.00         1
#             Explain Planning and Scheduling in software projects.       0.00      0.00      0.00         1
#                  Explain Polish Notation in computer programming.       0.00      0.00      0.00         1
#                                                Explain Processes.       0.00      0.00      0.00         1
# Explain Requirements Engineering Process in software development.       0.00      0.00      0.00         1
#                                    Explain Scheduling Algorithms.       0.00      0.00      0.00         1
#                                     Explain Training vs. Testing.       0.00      0.00      0.00         1
#                          Explain different programming languages.       0.00      0.00      0.00         1
#                                            Explain how APIs work.       0.00      0.00      0.00         1
#                        Explain recursion in computer programming.       0.00      0.00      0.00         1
#                             Explain the concept of event logging.       0.00      0.00      0.00         1
#                Explain the concept of existential quantification.       0.00      0.00      0.00         1
#                                 Explain the data science process.       0.00      0.00      0.00         1
#                                  Explain the types of VR systems.       0.00      0.00      0.00         1
#                                        Explain types of networks.       0.00      0.00      0.00         1
#
#                                                          accuracy                           0.17        35
#                                                         macro avg       0.01      0.03      0.01        35
#                                                      weighted avg       0.03      0.17      0.05        35
#
# Classification Report for patterns__003:
#                                              precision    recall  f1-score   support
#
#                                           0       0.94      1.00      0.97        29
#             What are JavaScript frameworks?       0.00      0.00      0.00         1
#      What are common cybersecurity threats?       0.00      0.00      0.00         0
#      What are the advantages of networking?       0.00      0.00      0.00         1
#            What are the applications of VR?       0.00      0.00      0.00         1
#   What are the benefits of using databases?       0.00      0.00      0.00         0
# What are the best practices in programming?       0.00      0.00      0.00         1
#    What are the tools used in data science?       0.00      0.00      0.00         1
#                 What are the types of APIs?       0.00      0.00      0.00         1
#
#                                    accuracy                           0.83        35
#                                   macro avg       0.10      0.11      0.11        35
#                                weighted avg       0.78      0.83      0.80        35
#
# done
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
